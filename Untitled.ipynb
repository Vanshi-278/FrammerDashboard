# %% [markdown]
# ## REQUIREMENTS

# %% [raw]
# #1 Drill downs
# #2 easy for non technical users
# #3 reusable
# #4 useful insights
#
#
# #5 single client can have different channels or workspace, channels can have different users, languagues..etc

# %% [markdown]
# ## USER

# %% [raw]
# • Founders / Leadership
# • Client Success teams
# • Operations teams
# • Editorial / Production teams
# • Tech / Product teams

# %% [markdown]
# ## Current Dashboard

# %% [raw]
# Filters
# summary on Uploaded, processed, published videos
# different kinds of videos .. each kind having total count, duration, published count
# summary charts on day-wise videos, channel wise charts and tables
# video-level details

# %% [markdown]
# ## Challenges:

# %% [raw]
# understanding hierachy -- (drill down dataset)
# better grouping
# better insights
# reusable logic
# ...show following things:  -- (anamoly detection)
# drop-offs
# underused channels and users
# high volume/low-publish patterns
# missing feilds
# error data
#
# NLP search
# Multi-dimension analytics -- (Pivot table thinking)

# %% [markdown]
# ## Things to be Answered

# %% [markdown]
# objectives given in ps pdf

# %% [markdown]
# ## Dashboard requirements

# %% [markdown]
# ## Features Required

# %% [raw]
# live chart -- for usage
# drill down (for multi dimension)

# %% [markdown]
# ## Dashboard Categories

# %% [raw]
# ### Founders
#
# KPIs:
# Total videos uploaded
# Total videos published
# Publish success rate
# Total content duration produced
# Active clients
#
# Visuals:
# Monthly upload trend (Monthly-chart -- total uploaded vs month)
# Monthly publishing trend (Monthly-chart -- total published vs month)
# Client contribution(client.csv -- publish count, created count)
# Platform distribution (channel-wise-publishing which channels active on which platform)
#
# ### Client success team
#
# components:
# Client activity (how frequent is the client active on platform , client.csv -- uploads)
# Publish success rate per client (client.csv -- publish count/ upload count need to take care of video lenght too )
# Platform usage per client
# Content distribution
#
# ### operation teams
# (focu on upload -> create -> publish flow)
#
# Upload → Created conversion
# Created → Published conversion
# Processing time
# Failure rate
#
# visuals:
# Pipeline funnel
# Duration processing trends
# Input type distribution
#
#
# ### production team
# Top performing content types
# Language distribution
# Platform success
# Output format performance
#
# ### tech / product team
# User activity
# Upload frequency
# Publish failure patterns
# API usage patterns
